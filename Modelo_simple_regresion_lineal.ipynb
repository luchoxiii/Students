# %% [markdown]
# ### Modelo simple de pronostico

# %% [markdown]
# Lucho Nov|2023
#
# Je veux by Zaz

# %% [markdown]
# ##### Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# #### Import dataset & code

# %%
#Generacion de la semilla
np.random.seed(42)

#Generacion de los datos
tamanio_m2 = np.random.randint(50, 300, 100)  
precio = tamanio_m2 * 2000 + np.random.randint(-100000, 10000, 100)  

data = {"tamanio_m2": tamanio_m2, "precio": precio}
df = pd.DataFrame(data)


#Separar variables
X = df[["tamanio_m2"]]
y = df[["precio"]]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)


# Crear y entrenar el modelo
modelo = LinearRegression()
modelo.fit(X_train, y_train)

# Realizar predicciones
predicciones = modelo.predict(X_test)

# Calcular error
error = mean_squared_error(y_test, predicciones)
r_error = np.sqrt(error)

# Imprimir resultados
print(f"Error cuadrático es: {error}")
print(f"Raíz del error cuadrático es: {r_error}")
# Out:
# Error cuadrático es: 1175086127.403715
# Raíz del error cuadrático es: 34279.5292762855

# %%
## Grafico

plt.subplot(1,2,1)
plt.scatter(X,y,color= "green",label="Datos reales", alpha=0.7)
plt.plot(X,modelo.predict(X),color ="red", label= "Linea de regresion")
plt.xlabel("Tamanio en m2")
plt.ylabel("Precio (U$D)")
plt.title("Relacion Tamanio & Precio")
plt.legend()
plt.show()
