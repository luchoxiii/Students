# %% [markdown]
# ## Proyect Iris

# %% [markdown]
# Lucho Feb|2022

# %% [markdown]
# #### Import Packages

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Import Data

# %%
df = pd.read_csv(r"Iris.csv")
df_raw = df.copy()
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# #### Pre-Process

# %%
df.rename({"SepalLengthCm" : "sep_1", "SepalWidthCm" : "sep_2", "PetalLengthCm" :"sep_3", "PetalWidthCm" : "sep_4",
       "Species" : "especie"}, axis = 1, inplace=True)

df.drop("Id", axis=1, inplace=True) #Eliminar filas
df.head()
# Out:
#    sep_1  sep_2  sep_3  sep_4      especie
# 0    5.1    3.5    1.4    0.2  Iris-setosa
# 1    4.9    3.0    1.4    0.2  Iris-setosa
# 2    4.7    3.2    1.3    0.2  Iris-setosa
# 3    4.6    3.1    1.5    0.2  Iris-setosa
# 4    5.0    3.6    1.4    0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sep_1    150 non-null    float64
#  1   sep_2    150 non-null    float64
#  2   sep_3    150 non-null    float64
#  3   sep_4    150 non-null    float64
#  4   especie  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#             sep_1       sep_2       sep_3       sep_4
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.especie.value_counts()
# Out:
# especie
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x="especie",palette="pastel")
plt.title('Species Distribution')
plt.ylabel("Cantidad")
plt.xlabel("Especies")
plt.show()
# Out:
# C:\Users\Lupin III\AppData\Local\Temp\ipykernel_12276\3134926042.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="especie",palette="pastel")

# %%
df.isna()
# Out:
#      sep_1  sep_2  sep_3  sep_4  especie
# 0    False  False  False  False    False
# 1    False  False  False  False    False
# 2    False  False  False  False    False
# 3    False  False  False  False    False
# 4    False  False  False  False    False
# ..     ...    ...    ...    ...      ...
# 145  False  False  False  False    False
# 146  False  False  False  False    False
# 147  False  False  False  False    False
# 148  False  False  False  False    False
# 149  False  False  False  False    False
#
# [150 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# sep_1      0
# sep_2      0
# sep_3      0
# sep_4      0
# especie    0
# dtype: int64

# %%
# 1. Histograma con KDE
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
sns.histplot(df['sep_1'], kde=True, bins=20, color='purple')
plt.title('Histograma con KDE - Longitud del sépalo')
plt.xlabel('Longitud del sépalo (cm)')
plt.ylabel('Frecuencia')

# 2. Boxplot
plt.subplot(1, 3, 2)
sns.boxplot(y=df['sep_1'], color='lightgreen')
plt.title('Boxplot - Longitud del sépalo')
plt.xlabel('Longitud del sépalo (cm)')
plt.ylabel('')

# 3. Violin plot
plt.subplot(1, 3, 3)
sns.violinplot(y=df['sep_1'], color='lightblue')
plt.title('Violin plot - Longitud del sépalo')
plt.xlabel('Longitud del sépalo (cm)')
plt.ylabel('')

# Mostrar los gráficos
plt.tight_layout()
plt.show()

# %%
# 1. Histograma con KDE
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
sns.histplot(df['sep_2'], kde=True, bins=20, color='purple')
plt.title('Histograma con KDE - Ancho del sépalo')
plt.xlabel('Ancho del sépalo (cm)')
plt.ylabel('Frecuencia')

# 2. Boxplot
plt.subplot(1, 3, 2)
sns.boxplot(y=df['sep_2'], color='lightgreen')
plt.title('Boxplot - Ancho del sépalo')
plt.xlabel('Ancho del sépalo (cm)')
plt.ylabel('')

# 3. Violin plot
plt.subplot(1, 3, 3)
sns.violinplot(y=df['sep_2'], color='lightblue')
plt.title('Violin plot - Ancho del sépalo')
plt.xlabel('Ancho del sépalo (cm)')
plt.ylabel('')

# Mostrar los gráficos
plt.tight_layout()
plt.show()

# %%
# 1. Histograma con KDE
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
sns.histplot(df['sep_3'], kde=True, bins=20, color='purple')
plt.title('Histograma con KDE - Longitud del Petalo')
plt.xlabel('Longitud del Petalo (cm)')
plt.ylabel('Frecuencia')

# 2. Boxplot
plt.subplot(1, 3, 2)
sns.boxplot(y=df['sep_3'], color='lightgreen')
plt.title('Boxplot - Longitud del Petalo')
plt.xlabel('Longitud del Petalo (cm)')
plt.ylabel('')

# 3. Violin plot
plt.subplot(1, 3, 3)
sns.violinplot(y=df['sep_3'], color='lightblue')
plt.title('Violin plot - Longitud del Petalo')
plt.xlabel('Longitud del Petalo (cm)')
plt.ylabel('')

# Mostrar los gráficos
plt.tight_layout()
plt.show()

# %%
# 1. Histograma con KDE
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
sns.histplot(df['sep_4'], kde=True, bins=20, color='purple')
plt.title('Histograma con KDE - Ancho del Petalo')
plt.xlabel('Ancho del Petalo (cm)')
plt.ylabel('Frecuencia')

# 2. Boxplot
plt.subplot(1, 3, 2)
sns.boxplot(y=df['sep_4'], color='lightgreen')
plt.title('Boxplot - Ancho del Petalo')
plt.xlabel('Ancho del Petalo (cm)')
plt.ylabel('')

# 3. Violin plot
plt.subplot(1, 3, 3)
sns.violinplot(y=df['sep_4'], color='lightblue')
plt.title('Violin plot - Ancho del Petalo')
plt.xlabel('Ancho del Petalo (cm)')
plt.ylabel('')

# Mostrar los gráficos
plt.tight_layout()
plt.show()

# %% [markdown]
# ###### Analisis Multivariable

# %%
# Crear una figura con una cuadrícula de 2x2 subgráficos
fig, axs = plt.subplots(2, 2, figsize=(14, 12))

# 1. Histograma de Longitud del Sépalo por Especie
sns.histplot(data=df, x='sep_1', hue='especie', multiple='stack', palette='Set1', bins=20, ax=axs[0, 0])
axs[0, 0].set_title('Histograma de Longitud del Sépalo por Especie')
axs[0, 0].set_xlabel('Longitud del Sépalo (cm)')
axs[0, 0].set_ylabel('Frecuencia')

# 2. Diagrama de Caja (Boxplot) de Longitud del Sépalo por Especie
sns.boxplot(data=df, x='especie', y='sep_1', palette='Set1', ax=axs[0, 1])
axs[0, 1].set_title('Diagrama de Caja de Longitud del Sépalo por Especie')
axs[0, 1].set_xlabel('Especie')
axs[0, 1].set_ylabel('Longitud del Sépalo (cm)')

# 3. Gráfico de Violín de Longitud del Sépalo por Especie
sns.violinplot(data=df, x='especie', y='sep_1', palette='Set1', ax=axs[1, 0])
axs[1, 0].set_title('Gráfico de Violín de Longitud del Sépalo por Especie')
axs[1, 0].set_xlabel('Especie')
axs[1, 0].set_ylabel('Longitud del Sépalo (cm)')

# 4. Gráfico de Dispersión (Scatter Plot) de Longitud del Sépalo por Especie
sns.scatterplot(data=df, x='sep_1', y='sep_3', hue='especie', palette='Set1', style='especie', ax=axs[1, 1])
axs[1, 1].set_title('Gráfico de Dispersión de Longitud del Sépalo y Longitud del Pétalo por Especie')
axs[1, 1].set_xlabel('Longitud del Sépalo (cm)')
axs[1, 1].set_ylabel('Longitud del Pétalo (cm)')
axs[1, 1].legend(title='Especie')

# Ajustar el espacio entre subgráficos
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lupin III\AppData\Local\Temp\ipykernel_12276\3528283680.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='especie', y='sep_1', palette='Set1', ax=axs[0, 1])
# C:\Users\Lupin III\AppData\Local\Temp\ipykernel_12276\3528283680.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='especie', y='sep_1', palette='Set1', ax=axs[1, 0])

# %%
sns.pairplot(df, hue="especie", markers=["o", "s", "D"], palette="Set1")
plt.show()

# %%
# Selecciona solo las columnas numéricas
df_1 = df.select_dtypes(include=['float64', 'int64'])
correlation_matrix = df_1.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', square=True)
plt.show()

# %% [markdown]
# ##### Conclusion

# %% [markdown]
# Es un conjunto de datos muy balanceado y se observa muy bien como correlacionan las variables. Donde se demuestra como es la relacion entre los las flores y los petalos.
